# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import gmaps
import postcodes_io_api
from scipy import stats
from scipy.stats import norm, skew #for some statistics

# %%
df0= pd.read_csv('pricelondon.csv')

# %%
df0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3242605 entries, 0 to 3242604
# Data columns (total 16 columns):
# ID             object
# Price          int64
# Date           object
# Postcode       object
# Type           object
# Newbuild       object
# Duration       object
# PAON           object
# SAON           object
# Street         object
# Locality       object
# Town           object
# District       object
# County         object
# Transaction    object
# Record         object
# dtypes: int64(1), object(15)
# memory usage: 395.8+ MB

# %%
df0.isnull().sum()
# Out:
# ID                   0
# Price                0
# Date                 0
# Postcode          5275
# Type                 0
# Newbuild             0
# Duration             0
# PAON                51
# SAON           2200850
# Street            2394
# Locality       1584162
# Town                 0
# District             0
# County               0
# Transaction          0
# Record               0
# dtype: int64

# %%
df0.Date=pd.to_datetime(df0.Date)

# %%
df0.isna().sum()
# Out:
# ID                   0
# Price                0
# Date                 0
# Postcode          5275
# Type                 0
# Newbuild             0
# Duration             0
# PAON                51
# SAON           2200850
# Street            2394
# Locality       1584162
# Town                 0
# District             0
# County               0
# Transaction          0
# Record               0
# dtype: int64

# %%
df0 = df0.drop(labels=['Locality','SAON','Record'], axis=1)

# %%
df0 = df0.dropna()

# %%
df0.isna().sum()
# Out:
# ID             0
# Price          0
# Date           0
# Postcode       0
# Type           0
# Newbuild       0
# Duration       0
# PAON           0
# Street         0
# Town           0
# District       0
# County         0
# Transaction    0
# dtype: int64

# %%
df0 = df0.reset_index(drop=True)

# %%
df0 = df0[df0.Newbuild=='Y']
df0 = df0[df0.Type!='O']

# %%
district = df0.District.unique().tolist()

# %%
df0 = df0.sort_values(by='Date')

# %%
dis = dict()

for i in district:
    dis[i] = df0[df0.District == i]

# %%
for key,val in dis.items():
    df0[key] = dis[key]['Price'].rolling(200).mean()

# %%
sns.lineplot(data=df0, x='Date',y='SUTTON')

# %%
plt.figure(figsize=(20,10))
sns.lineplot(data=df0, x='Date',y='SOUTHWARK')
sns.lineplot(data=df0, x='Date',y='EALING')
sns.lineplot(data=df0, x='Date',y='CAMDEN')
plt.legend(labels=['SOUTHWARK', 'EALING', 'CAMDEN'])
plt.show()

# %%
df = df[df0.Newbuild=='Y']
df = df[df0.Type!='O']
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %% [markdown]
# Exploring EALING

# %%
ealing = df[df.District == 'EALING'].reset_index(drop=True)

# %%
sns.lineplot(data=ealing, x='Date',y='Price')

# %%
ealing.Price.describe()
# Out:
# count    1.125210e+05
# mean     2.897181e+05
# std      2.606811e+05
# min      1.000000e+00
# 25%      1.350000e+05
# 50%      2.263300e+05
# 75%      3.550000e+05
# max      1.125000e+07
# Name: Price, dtype: float64

# %%
eal10 = ealing[ealing.Date > '2010-01-01'].sort_values(by='Date').reset_index()

# %%
eal10['roll'] = eal10['Price'].rolling(100).mean()

# %%
sns.lineplot(data=eal10, x='Date',y='roll')

# %%
eal10['roll'].describe()
# Out:
# count     33023.000000
# mean     478841.383534
# std       90395.507955
# min      153630.030000
# 25%      401328.210000
# 50%      490744.330000
# 75%      549521.370000
# max      702114.230000
# Name: roll, dtype: float64

# %%
eal10[eal10.roll  < 200000]
# Out:
#         index                                      ID   Price       Date  \
# 30039  108975  {79A74E22-7EA3-1289-E053-6B04A8C01627}  131028 2018-09-12
# 30040  108934  {79A74E22-7E7A-1289-E053-6B04A8C01627}   97258 2018-09-12
# 30041  108974  {79A74E22-7EA2-1289-E053-6B04A8C01627}   97933 2018-09-12
# 30042  108973  {79A74E22-7EA1-1289-E053-6B04A8C01627}  100635 2018-09-12
# 30043  108935  {79A74E22-7E7B-1289-E053-6B04A8C01627}  120221 2018-09-12
# 30044  108977  {79A74E22-7EA5-1289-E053-6B04A8C01627}  100635 2018-09-12
# 30045  108970  {79A74E22-7E9D-1289-E053-6B04A8C01627}   99959 2018-09-12
# 30046  108972  {79A74E22-7E9F-1289-E053-6B04A8C01627}  128326 2018-09-12
# 30047  108971  {79A74E22-7E9E-1289-E053-6B04A8C01627}  128326 2018-09-12
# 30048  108936  {79A74E22-7E7C-1289-E053-6B04A8C01627}  128326 2018-09-12
# 30049  108937  {79A74E22-7E7D-1289-E053-6B04A8C01627}  129677 2018-09-12
# 30050  108854  {7C2D0701-1928-4963-E053-6B04A8C07B97}  300000 2018-09-13
# 30051  110141  {773788C2-ED6A-2CE4-E053-6C04A8C05E57}  382000 2018-09-13
# 30052  110135  {773788C2-E921-2CE4-E053-6C04A8C05E57}  750000 2018-09-13
# 30053  110232  {8355F008-A3FF-55C5-E053-6B04A8C0D090}  600000 2018-09-13
# 30054  110044  {773788C2-E7E2-2CE4-E053-6C04A8C05E57}  845000 2018-09-13
# 30055  108757  {7E86B6FA-703A-458C-E053-6B04A8C0C84C}  575000 2018-09-13
# 30056  108307  {773788C2-30C4-2CE4-E053-6C04A8C05E57}  930000 2018-09-13
# 30057  110209  {773788C3-7A9F-2CE4-E053-6C04A8C05E57}  460000 2018-09-13
# 30058  110147  {7C2D06FF-9D89-4963-E053-6B04A8C07B97}  256870 2018-09-14
# 30059  110095  {773788C2-ECBA-2CE4-E053-6C04A8C05E57}  230000 2018-09-14
# 30060  108069  {773788C2-31E0-2CE4-E053-6C04A8C05E57}  360000 2018-09-14
# 30061  107938  {79A74E21-DDC0-1289-E053-6B04A8C01627}  410000 2018-09-14
# 30062  107970  {773788C2-32E1-2CE4-E053-6C04A8C05E57}  710000 2018-09-14
# 30063  107846  {80E1AA97-A835-7BF8-E053-6C04A8C00BF2}  450000 2018-09-14
# 30064  108585  {773788C2-3100-2CE4-E053-6C04A8C05E57}  750000 2018-09-14
#
#       Postcode Type Newbuild Duration                PAON  \
# 30039  UB1 1FL    F        Y        L        NEWELL HOUSE
# 30040  UB1 1FN    F        Y        L        BRAVEY HOUSE
# 30041  UB1 1FL    F        Y        L        NEWELL HOUSE
# 30042  UB1 1FL    F        Y        L        NEWELL HOUSE
# 30043  UB1 1FN    F        Y        L        BRAVEY HOUSE
# 30044  UB1 1FL    F        Y        L        NEWELL HOUSE
# 30045  UB1 1FL    F        Y        L        NEWELL HOUSE
# 30046  UB1 1FL    F        Y        L        NEWELL HOUSE
# 30047  UB1 1FL    F        Y        L        NEWELL HOUSE
# 30048  UB1 1FN    F        Y        L        BRAVEY HOUSE
# 30049  UB1 1FN    F        Y        L        BRAVEY HOUSE
# 30050   W7 3SQ    F        N        L                   8
# 30051  UB5 4DN    T        N        F                  11
# 30052  W13 9AP    T        N        F                  17
# 30053   W3 8YG    F        N        L         DONNE COURT
# 30054   W7 2BT    T        N        F                  74
# 30055  UB6 8AT    F        Y        L     HOOVER BUILDING
# 30056  W13 9UY    S        N        F                  13
# 30057  UB1 2LP    T        N        F                 12A
# 30058   W3 7RT    F        N        L                  1A
# 30059  UB2 5PA    T        N        F                   8
# 30060   W3 9AF    F        N        L  COPPERFIELDS COURT
# 30061  UB2 4EQ    T        N        F                  68
# 30062   W5 2QB    F        N        L                  17
# 30063  UB2 4FU    F        Y        L        LEVETT HOUSE
# 30064   W5 2UZ    F        N        L   HAVEN GREEN COURT
#
#                     Street       Town District          County Transaction  \
# 30039         SAMARA DRIVE   SOUTHALL   EALING  GREATER LONDON           B
# 30040         SAMARA DRIVE   SOUTHALL   EALING  GREATER LONDON           B
# 30041         SAMARA DRIVE   SOUTHALL   EALING  GREATER LONDON           B
# 30042         SAMARA DRIVE   SOUTHALL   EALING  GREATER LONDON           B
# 30043         SAMARA DRIVE   SOUTHALL   EALING  GREATER LONDON           B
# 30044         SAMARA DRIVE   SOUTHALL   EALING  GREATER LONDON           B
# 30045         SAMARA DRIVE   SOUTHALL   EALING  GREATER LONDON           B
# 30046         SAMARA DRIVE   SOUTHALL   EALING  GREATER LONDON           B
# 30047         SAMARA DRIVE   SOUTHALL   EALING  GREATER LONDON           B
# 30048         SAMARA DRIVE   SOUTHALL   EALING  GREATER LONDON           B
# 30049         SAMARA DRIVE   SOUTHALL   EALING  GREATER LONDON           B
# 30050       JESSAMINE ROAD     LONDON   EALING  GREATER LONDON           B
# 30051      SUSSEX CRESCENT   NORTHOLT   EALING  GREATER LONDON           A
# 30052      BROOMFIELD ROAD     LONDON   EALING  GREATER LONDON           A
# 30053    BOLLO BRIDGE ROAD     LONDON   EALING  GREATER LONDON           A
# 30054     CLITHEROW AVENUE     LONDON   EALING  GREATER LONDON           A
# 30055       WESTERN AVENUE  GREENFORD   EALING  GREATER LONDON           A
# 30056       RAYMOND AVENUE     LONDON   EALING  GREATER LONDON           A
# 30057         BURNS AVENUE   SOUTHALL   EALING  GREATER LONDON           B
# 30058         THIRD AVENUE     LONDON   EALING  GREATER LONDON           A
# 30059        MONTAGUE WAYE   SOUTHALL   EALING  GREATER LONDON           A
# 30060  GUNNERSBURY GARDENS     LONDON   EALING  GREATER LONDON           A
# 30061         HAMMOND ROAD   SOUTHALL   EALING  GREATER LONDON           A
# 30062    NORTH COMMON ROAD     LONDON   EALING  GREATER LONDON           A
# 30063        DENMAN AVENUE   SOUTHALL   EALING  GREATER LONDON           A
# 30064          HAVEN GREEN     LONDON   EALING  GREATER LONDON           A
#
#       Record       roll   logPrice
# 30039      A  199064.47  11.783174
# 30040      A  188137.05  11.485133
# 30041      A  180866.38  11.492049
# 30042      A  180512.73  11.519265
# 30043      A  169064.94  11.697095
# 30044      A  164521.29  11.519265
# 30045      A  160890.88  11.512525
# 30046      A  160904.39  11.762337
# 30047      A  157937.65  11.762337
# 30048      A  158261.84  11.762337
# 30049      A  154559.11  11.772810
# 30050      A  156275.85  12.611541
# 30051      A  159130.03  12.853179
# 30052      A  153630.03  13.527830
# 30053      A  158643.94  13.304687
# 30054      A  165797.17  13.647093
# 30055      A  170277.42  13.262127
# 30056      A  178577.83  13.742941
# 30057      A  181948.60  13.038984
# 30058      A  178117.30  12.456329
# 30059      A  179404.20  12.345839
# 30060      A  181666.91  12.793862
# 30061      A  180366.91  12.923915
# 30062      A  186487.58  13.473022
# 30063      A  189987.99  13.017005
# 30064      A  196204.73  13.527830

# %%
sns.distplot(eal10['Price'] , fit=norm);

# Get the fitted parameters used by the function
(mu, sigma) = norm.fit(eal10['Price'])
print( '\n mu = {:.2f} and sigma = {:.2f}\n'.format(mu, sigma))

#Now plot the distribution
plt.legend(['Normal dist. ($\mu=$ {:.2f} and $\sigma=$ {:.2f} )'.format(mu, sigma)],
            loc='best')
plt.ylabel('Frequency')
plt.title('SalePrice distribution')

#Get also the QQ-plot
fig = plt.figure()
res = stats.probplot(eal10['Price'], plot=plt)
plt.show()
# Out:
#  mu = 478890.61 and sigma = 344677.95

# %%
#We use the numpy fuction log1p which  applies log(1+x) to all elements of the column
eal10['logPrice'] = np.log1p(eal10['Price'])

#Check the new distribution 
sns.distplot(eal10['logPrice'] , fit=norm);

# Get the fitted parameters used by the function
(mu, sigma) = norm.fit(eal10['logPrice'])
print( '\n mu = {:.2f} and sigma = {:.2f}\n'.format(mu, sigma))

#Now plot the distribution
plt.legend(['Normal dist. ($\mu=$ {:.2f} and $\sigma=$ {:.2f} )'.format(mu, sigma)],
            loc='best')
plt.ylabel('Frequency')
plt.title('SalePrice distribution')

#Get also the QQ-plot
fig = plt.figure()
res = stats.probplot(eal10['logPrice'], plot=plt)
plt.show()
# Out:
#  mu = 12.90 and sigma = 0.58

# %% [markdown]
# ---
# exploring non-new sales
# ---

# %%
df
# Out:
#                                              ID    Price       Date  Postcode  \
# 0        {A4315312-90D5-42D1-85F6-3F3209E9C709}    59995 1995-10-19   SM6 7AG
# 1        {CEA5DDF7-F936-4DB1-934B-42C5CBF28AD8}   292500 1995-08-31   HA3 6DD
# 2        {613A5A52-B86D-4F69-B56D-49E35D0A3C64}    84000 1995-07-28   RM5 3YL
# 3        {7624595C-53BF-4AC8-9683-42C5F7CFA5C6}    66500 1995-07-12   SE6 4EW
# 4        {A5053A3C-81C1-4CD1-8DEF-49E3C462498A}    67995 1995-09-20   N22 6NP
# ...                                         ...      ...        ...       ...
# 3242600  {87E1551E-EEBD-6405-E053-6C04A8C0B2EE}   400000 2019-03-26   KT6 7EL
# 3242601  {87E1551E-EEBE-6405-E053-6C04A8C0B2EE}   590000 2019-04-10   HA8 5EN
# 3242602  {8F1B26BD-4348-53DB-E053-6C04A8C03649}   510000 2019-07-09   SE9 3PB
# 3242603  {8F1B26BD-4349-53DB-E053-6C04A8C03649}   550000 2019-05-31  SW16 6DL
# 3242604  {8F1B26BD-4347-53DB-E053-6C04A8C03649}  6750000 2019-06-28   NW1 8YB
#
#         Type Newbuild Duration  PAON               Street        Town  \
# 0          F        Y        L    55        CARAWAY PLACE  WALLINGTON
# 1          D        Y        F    11     LAVENDER GARDENS      HARROW
# 2          T        N        F    40  MOUNT PLEASANT ROAD     ROMFORD
# 3          T        N        F     6         BROXTED ROAD      LONDON
# 4          T        N        F   155        MORLEY AVENUE      LONDON
# ...      ...      ...      ...   ...                  ...         ...
# 3242600    T        N        F   440           EWELL ROAD    SURBITON
# 3242601    T        N        F  123A   BURNT OAK BROADWAY     EDGWARE
# 3242602    T        N        F    58       MONTBELLE ROAD      LONDON
# 3242603    T        N        F    67     BLEGBOROUGH ROAD      LONDON
# 3242604    T        N        F     2       CHALCOT SQUARE      LONDON
#
#                      District          County Transaction Record
# 0                      SUTTON  GREATER LONDON           A      A
# 1                      HARROW  GREATER LONDON           A      A
# 2                    HAVERING  GREATER LONDON           A      A
# 3                    LEWISHAM  GREATER LONDON           A      A
# 4                    HARINGEY  GREATER LONDON           A      A
# ...                       ...             ...         ...    ...
# 3242600  KINGSTON UPON THAMES  GREATER LONDON           B      A
# 3242601                HARROW  GREATER LONDON           B      A
# 3242602             GREENWICH  GREATER LONDON           A      A
# 3242603            WANDSWORTH  GREATER LONDON           A      A
# 3242604                CAMDEN  GREATER LONDON           A      A
#
# [3202940 rows x 14 columns]

# %%
dfn = df0[df0.Newbuild=='N']
dfn = dfn[df0.Type!='O']
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %%
dfn.reset_index(drop=True)
# Out:
#                                              ID    Price       Date  Postcode  \
# 0        {613A5A52-B86D-4F69-B56D-49E35D0A3C64}    84000 1995-07-28   RM5 3YL
# 1        {7624595C-53BF-4AC8-9683-42C5F7CFA5C6}    66500 1995-07-12   SE6 4EW
# 2        {A5053A3C-81C1-4CD1-8DEF-49E3C462498A}    67995 1995-09-20   N22 6NP
# 3        {65B8997F-8463-4B52-BB22-42C64CA58448}    80000 1995-06-01   BR3 3QG
# 4        {2910710F-9952-4AF1-8178-3BA1F0A172F3}    77000 1995-07-26  SW16 4QD
# ...                                         ...      ...        ...       ...
# 2915160  {87E1551E-EEBD-6405-E053-6C04A8C0B2EE}   400000 2019-03-26   KT6 7EL
# 2915161  {87E1551E-EEBE-6405-E053-6C04A8C0B2EE}   590000 2019-04-10   HA8 5EN
# 2915162  {8F1B26BD-4348-53DB-E053-6C04A8C03649}   510000 2019-07-09   SE9 3PB
# 2915163  {8F1B26BD-4349-53DB-E053-6C04A8C03649}   550000 2019-05-31  SW16 6DL
# 2915164  {8F1B26BD-4347-53DB-E053-6C04A8C03649}  6750000 2019-06-28   NW1 8YB
#
#         Type Newbuild Duration  PAON SAON               Street    Locality  \
# 0          T        N        F    40  NaN  MOUNT PLEASANT ROAD     ROMFORD
# 1          T        N        F     6  NaN         BROXTED ROAD      LONDON
# 2          T        N        F   155  NaN        MORLEY AVENUE      LONDON
# 3          T        N        F    25  NaN         DERRICK ROAD   BECKENHAM
# 4          T        N        F   145  NaN        STANFORD ROAD      LONDON
# ...      ...      ...      ...   ...  ...                  ...         ...
# 2915160    T        N        F   440  NaN           EWELL ROAD    TOLWORTH
# 2915161    T        N        F  123A  NaN   BURNT OAK BROADWAY         NaN
# 2915162    T        N        F    58  NaN       MONTBELLE ROAD  NEW ELTHAM
# 2915163    T        N        F    67  NaN     BLEGBOROUGH ROAD         NaN
# 2915164    T        N        F     2  NaN       CHALCOT SQUARE         NaN
#
#               Town              District          County Transaction Record
# 0          ROMFORD              HAVERING  GREATER LONDON           A      A
# 1           LONDON              LEWISHAM  GREATER LONDON           A      A
# 2           LONDON              HARINGEY  GREATER LONDON           A      A
# 3        BECKENHAM               BROMLEY  GREATER LONDON           A      A
# 4           LONDON               CROYDON  GREATER LONDON           A      A
# ...            ...                   ...             ...         ...    ...
# 2915160   SURBITON  KINGSTON UPON THAMES  GREATER LONDON           B      A
# 2915161    EDGWARE                HARROW  GREATER LONDON           B      A
# 2915162     LONDON             GREENWICH  GREATER LONDON           A      A
# 2915163     LONDON            WANDSWORTH  GREATER LONDON           A      A
# 2915164     LONDON                CAMDEN  GREATER LONDON           A      A
#
# [2915165 rows x 16 columns]

# %%
dfn.groupby('District')['ID'].nunique().sort_values(ascending=False)
# Out:
# District
# WANDSWORTH                151620
# BROMLEY                   142307
# CROYDON                   141131
# BARNET                    122613
# ENFIELD                   110985
# LAMBETH                   109519
# EALING                    105477
# LEWISHAM                  102003
# CITY OF WESTMINSTER       100674
# HILLINGDON                 98197
# REDBRIDGE                  96189
# BEXLEY                     93589
# RICHMOND UPON THAMES       93347
# WALTHAM FOREST             91626
# HAVERING                   89632
# SUTTON                     85981
# SOUTHWARK                  85312
# MERTON                     83884
# HARINGEY                   80865
# GREENWICH                  78918
# BRENT                      78634
# KENSINGTON AND CHELSEA     78067
# HOUNSLOW                   77103
# NEWHAM                     75447
# HARROW                     74394
# HAMMERSMITH AND FULHAM     73524
# CAMDEN                     72776
# TOWER HAMLETS              71564
# KINGSTON UPON THAMES       70902
# ISLINGTON                  60303
# HACKNEY                    58029
# BARKING AND DAGENHAM       55077
# CITY OF LONDON              5476
# Name: ID, dtype: int64

# %%
df.groupby('District')['ID'].nunique().sort_values(ascending=False)
# Out:
# District
# WANDSWORTH                167520
# BROMLEY                   150125
# CROYDON                   149348
# BARNET                    137558
# LAMBETH                   120441
# ENFIELD                   117532
# EALING                    112521
# CITY OF WESTMINSTER       111848
# LEWISHAM                  110911
# HILLINGDON                105996
# TOWER HAMLETS             105337
# REDBRIDGE                 103764
# SOUTHWARK                 102872
# BEXLEY                     98576
# RICHMOND UPON THAMES       98360
# HAVERING                   95947
# GREENWICH                  95735
# WALTHAM FOREST             94956
# SUTTON                     91898
# NEWHAM                     88794
# MERTON                     88523
# HOUNSLOW                   87307
# BRENT                      84821
# HARINGEY                   83542
# KENSINGTON AND CHELSEA     80433
# HARROW                     80140
# HAMMERSMITH AND FULHAM     78119
# CAMDEN                     76963
# KINGSTON UPON THAMES       76241
# ISLINGTON                  70095
# HACKNEY                    68352
# BARKING AND DAGENHAM       60698
# CITY OF LONDON              7667
# Name: ID, dtype: int64

# %%
ealingn = dfn[dfn.District == 'EALING'].reset_index(drop=True)

# %%
sns.lineplot(data=ealingn, x='Date',y='Price')
